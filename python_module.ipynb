# %% [markdown]
# ### Electric Vehicle Data Analysis Project

# %% [markdown]
# #### Life cycle of Machine learning Project

# %% [markdown]
# - Understanding the Problem Statement
# - Data Collection
# - Data Checks to perform
# - Exploratory data analysis
# - Data Pre-Processing

# %% [markdown]
# ### 1) Problem statement
# - Analyze an electric vehicle (EV) dataset to uncover key factors impacting price, range, and energy efficiency. Provide data-driven insights and actionable recommendations to support EV market growth and product innovation.
#
#
# ### 2) Dataset
# - Dataset Source - FEV-data-Excel.xlsx

# %% [markdown]
# ### Task 1: Data Cleaning and Preprocessing: Ensure data quality before analysis. (10 Marks)

# %% [markdown]
# ### Import Data and Required Packages
# ####  Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv("FEV-data-Excel.xlsx - Auta elektryczne.csv")

# %% [markdown]
# #### Show Top 5 Records

# %%
df.head()
# Out:
#                       Car full name  Make                        Model  \
# 0            Audi e-tron 55 quattro  Audi            e-tron 55 quattro
# 1            Audi e-tron 50 quattro  Audi            e-tron 50 quattro
# 2             Audi e-tron S quattro  Audi             e-tron S quattro
# 3  Audi e-tron Sportback 50 quattro  Audi  e-tron Sportback 50 quattro
# 4  Audi e-tron Sportback 55 quattro  Audi  e-tron Sportback 55 quattro
#
#    Minimal price (gross) [PLN]  Engine power [KM]  Maximum torque [Nm]  \
# 0                       345700                360                  664
# 1                       308400                313                  540
# 2                       414900                503                  973
# 3                       319700                313                  540
# 4                       357000                360                  664
#
#         Type of brakes Drive type  Battery capacity [kWh]  Range (WLTP) [km]  \
# ...

# %% [markdown]
# #### Shape of the dataset

# %%
df.shape
# Out:
# (53, 25)

# %% [markdown]
# ### Data Checks to perform
#
# - Check Missing values
# - Check Duplicates
# - Check data type
# - Check the number of unique values of each column
# - Check statistics of data set
# - Check various categories present in the different categorical column

# %% [markdown]
# ### Check Missing values

# %%
df.isna().sum()
# Out:
# Car full name                             0
# Make                                      0
# Model                                     0
# Minimal price (gross) [PLN]               0
# Engine power [KM]                         0
# Maximum torque [Nm]                       0
# Type of brakes                            1
# Drive type                                0
# Battery capacity [kWh]                    0
# Range (WLTP) [km]                         0
# Wheelbase [cm]                            0
# Length [cm]                               0
# Width [cm]                                0
# Height [cm]                               0
# Minimal empty weight [kg]                 0
# Permissable gross weight [kg]             8
# Maximum load capacity [kg]                8
# Number of seats                           0
# Number of doors                           0
# Tire size [in]                            0
# Maximum speed [kph]                       0
# ...

# %% [markdown]
# #### There are no missing values in the data set

# %% [markdown]
# ### Check Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### There are no duplicates  values in the data set

# %% [markdown]
# ### Check data types

# %%
# Check Null and Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 25 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Car full name                           53 non-null     object
#  1   Make                                    53 non-null     object
#  2   Model                                   53 non-null     object
#  3   Minimal price (gross) [PLN]             53 non-null     int64
#  4   Engine power [KM]                       53 non-null     int64
#  5   Maximum torque [Nm]                     53 non-null     int64
#  6   Type of brakes                          52 non-null     object
#  7   Drive type                              53 non-null     object
#  8   Battery capacity [kWh]                  53 non-null     float64
#  9   Range (WLTP) [km]                       53 non-null     int64
# ...

# %% [markdown]
# ### Checking the number of unique values of each column

# %%
df.nunique()
# Out:
# Car full name                             53
# Make                                      20
# Model                                     53
# Minimal price (gross) [PLN]               50
# Engine power [KM]                         27
# Maximum torque [Nm]                       31
# Type of brakes                             2
# Drive type                                 3
# Battery capacity [kWh]                    24
# Range (WLTP) [km]                         47
# Wheelbase [cm]                            29
# Length [cm]                               34
# Width [cm]                                30
# Height [cm]                               36
# Minimal empty weight [kg]                 46
# Permissable gross weight [kg]             35
# Maximum load capacity [kg]                35
# Number of seats                            6
# Number of doors                            3
# Tire size [in]                             8
# Maximum speed [kph]                       21
# ...

# %% [markdown]
# ### Check statistics of data set

# %%
df.describe()
# Out:
#        Minimal price (gross) [PLN]  Engine power [KM]  Maximum torque [Nm]  \
# count                    53.000000          53.000000            53.000000
# mean                 246158.509434         269.773585           460.037736
# std                  149187.485190         181.298589           261.647000
# min                   82050.000000          82.000000           160.000000
# 25%                  142900.000000         136.000000           260.000000
# 50%                  178400.000000         204.000000           362.000000
# 75%                  339480.000000         372.000000           640.000000
# max                  794000.000000         772.000000          1140.000000
#
#        Battery capacity [kWh]  Range (WLTP) [km]  Wheelbase [cm]  Length [cm]  \
# count               53.000000          53.000000       53.000000    53.000000
# mean                62.366038         376.905660      273.581132   442.509434
# ...

# %% [markdown]
# ### Exploring Data

# %%
# Univariate Analysis - Distribution plots
numerical_cols = [
    'Minimal price (gross) [PLN]', 'Engine power [KM]', 'Maximum torque [Nm]', 'Battery capacity [kWh]', 
    'Range (WLTP) [km]', 'Wheelbase [cm]', 'Length [cm]', 'Width [cm]', 'Height [cm]', 
    'Minimal empty weight [kg]', 'Permissable gross weight [kg]','Maximum load capacity [kg]', 'Maximum speed [kph]', 
    'Boot capacity (VDA) [l]', 'Acceleration 0-100 kph [s]', 'mean - Energy consumption [kWh/100 km]'
]

# %%
# Plotting distributions for numerical columns
plt.figure(figsize=(20, 15))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(5, 4, i)
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Bivariate Analysis - Scatterplots and Correlations
# Scatterplot of Minimal price (gross) [PLN] vs other key metrics
plt.figure(figsize=(15, 10))
sns.pairplot(df, 
             x_vars=['Engine power [KM]', 'Battery capacity [kWh]', 'Range (WLTP) [km]', 'mean - Energy consumption [kWh/100 km]'], 
             y_vars='Minimal price (gross) [PLN]', 
             height=4, aspect=0.8, kind='scatter')
plt.suptitle('Price vs Key Metrics', y=1.02)
plt.show()

# %%
# Bivariate Analysis - Categorical vs Numerical
# Boxplot of Minimal price (gross) [PLN] by Drive type and Type of brakes
plt.figure(figsize=(12, 6))

# Boxplot for Drive type
plt.subplot(1, 2, 1)
sns.boxplot(x='Drive type', y='Minimal price (gross) [PLN]', data=df, palette='pastel')
plt.title('Price by Drive Type')

# Boxplot for Type of brakes
plt.subplot(1, 2, 2)
sns.boxplot(x='Type of brakes', y='Minimal price (gross) [PLN]', data=df, palette='pastel')
plt.title('Price by Type of Brakes')

plt.tight_layout()
plt.show()

# %%
# Hypothesis Testing - Comparing means for Electric Range based on Drive Type
from scipy.stats import ttest_ind

# Filtering the data for t-test
df_drive_1 = df[df['Drive type'] == 1]['Range (WLTP) [km]']
df_drive_2 = df[df['Drive type'] == 2]['Range (WLTP) [km]']

# T-test for Drive Type differences in Range
t_stat, p_value = ttest_ind(df_drive_1, df_drive_2, nan_policy='omit')
print(f"T-statistic: {t_stat}, P-value: {p_value}")
if p_value < 0.05:
    print("Reject null hypothesis: Significant difference in range based on drive type")
else:
    print("Fail to reject null hypothesis: No significant difference in range based on drive type")
# Out:
# T-statistic: nan, P-value: nan
# Fail to reject null hypothesis: No significant difference in range based on drive type

# %% [markdown]
# ### Task 2: Provide an overview of the dataset : "What does the data suggest about the growth of electric vehicles?" (10 Marks)

# %% [markdown]
# The dataset contains 53 unique models from 20 manufacturers, indicating a significant expansion in the EV market. This growth reflects increased competition and innovation as manufacturers aim to cater to diverse consumer preferences.

# %% [markdown]
# ### Task 3: Outlier Detection : Identify and analyze outliers in the dataset. (10 Marks)

# %% [markdown]
# #### Boxplots are a common way to detect outliers visually. Outliers typically appear as points outside the "whiskers" of a boxplot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting figure size for better visibility
plt.figure(figsize=(16, 12))

# Plotting boxplots for each numerical feature to visually inspect outliers
for i, column in enumerate(df.select_dtypes(include='number').columns, 1):
    plt.subplot(5, 4, i)
    sns.boxplot(y=df[column], color='skyblue')
    plt.title(f'Boxplot of {column}')
    plt.tight_layout()

plt.show()

# %% [markdown]
# ### Task 4: Correlation Analysis : Explore relationships between numerical columns (10 Marks)

# %%
# Correlation Matrix Heatmap
plt.figure(figsize=(12, 10))
correlation_matrix = df[numerical_cols].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ### Task 5: Trend Identification : Identify significant trends in the dataset. (10 Marks)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatterplots with regression lines to identify trends between features
plt.figure(figsize=(15, 10))

# Plotting Price vs. Battery Capacity
plt.subplot(2, 2, 1)
sns.regplot(x='Battery capacity [kWh]', y='Minimal price (gross) [PLN]', data=df)
plt.title('Price vs Battery Capacity')

# Plotting Price vs. Engine Power
plt.subplot(2, 2, 2)
sns.regplot(x='Engine power [KM]', y='Minimal price (gross) [PLN]', data=df)
plt.title('Price vs Engine Power')

# Plotting Battery Capacity vs. Range (WLTP)
plt.subplot(2, 2, 3)
sns.regplot(x='Battery capacity [kWh]', y='Range (WLTP) [km]', data=df, scatter_kws={'alpha':0.5})
plt.title('Battery Capacity vs Range')

# Plotting Energy Consumption vs Range (WLTP)
plt.subplot(2, 2, 4)
sns.regplot(x='mean - Energy consumption [kWh/100 km]', y='Range (WLTP) [km]', data=df, scatter_kws={'alpha':0.5})
plt.title('Energy Consumption vs Range')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Trend Analysis by Categorical Features
# Analyzing trends across different categories, such as drive type or brake type, can reveal how these features impact price or range.

# %%
plt.figure(figsize=(12, 6))

# Plotting Price vs Drive Type
plt.subplot(1, 2, 1)
sns.boxplot(x='Drive type', y='Minimal price (gross) [PLN]', data=df, palette='pastel')
plt.title('Price by Drive Type')

# Plotting Price vs Brake Type
plt.subplot(1, 2, 2)
sns.boxplot(x='Type of brakes', y='Minimal price (gross) [PLN]', data=df, palette='pastel')
plt.title('Price by Brake Type')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 6: Manufacturer Analysis : Analyze the performance of manufacturers in the electric vehicle market. (10 Marks)

# %% [markdown]
# #### Market Representation by Manufacturer Count the number of models each manufacturer offers in the dataset to understand market share.

# %%
# Count of models by each manufacturer
manufacturer_counts = df['Make'].value_counts()

# Plotting the count of models per manufacturer
plt.figure(figsize=(12, 6))
sns.barplot(x=manufacturer_counts.index, y=manufacturer_counts.values, palette='viridis')
plt.xticks(rotation=90)
plt.title("Number of Models Offered by Each Manufacturer")
plt.xlabel("Manufacturer")
plt.ylabel("Number of Models")
plt.show()

# %% [markdown]
# #### Average Price by Manufacturer Compute and plot the average price for each manufacturer to identify those positioned in the high-end vs. budget segments of the EV market.

# %%
# Calculating average price per manufacturer
avg_price_by_manufacturer = df.groupby('Make')['Minimal price (gross) [PLN]'].mean().sort_values(ascending=False)

# Plotting average price by manufacturer
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_price_by_manufacturer.index, y=avg_price_by_manufacturer.values, palette='coolwarm')
plt.xticks(rotation=90)
plt.title("Average Price by Manufacturer")
plt.xlabel("Manufacturer")
plt.ylabel("Average Price (PLN)")
plt.show()

# %% [markdown]
# ### Task 7: Identify top-performing EVs in terms of range, acceleration, and maximum speed. (10 Marks)

# %%
# Sorting the EVs by Range (WLTP), Acceleration, and Maximum Speed
top_range_vehicles = df[['Car full name', 'Range (WLTP) [km]', 'Minimal price (gross) [PLN]']].sort_values(by='Range (WLTP) [km]', ascending=False).head(10)
top_acceleration_vehicles = df[['Car full name', 'Acceleration 0-100 kph [s]', 'Minimal price (gross) [PLN]']].sort_values(by='Acceleration 0-100 kph [s]').head(10)
top_speed_vehicles = df[['Car full name', 'Maximum speed [kph]', 'Minimal price (gross) [PLN]']].sort_values(by='Maximum speed [kph]', ascending=False).head(10)

# Displaying the top 10 EVs for each category
print("Top 10 EVs by Range:")
print(top_range_vehicles[['Car full name', 'Range (WLTP) [km]', 'Minimal price (gross) [PLN]']])

print("\nTop 10 EVs by Acceleration (0-100 kph):")
print(top_acceleration_vehicles[['Car full name', 'Acceleration 0-100 kph [s]', 'Minimal price (gross) [PLN]']])

print("\nTop 10 EVs by Maximum Speed:")
print(top_speed_vehicles[['Car full name', 'Maximum speed [kph]', 'Minimal price (gross) [PLN]']])
# Out:
# Top 10 EVs by Range:
#                            Car full name  Range (WLTP) [km]  \
# 42         Tesla Model S Long Range Plus                652
# 43             Tesla Model S Performance                639
# 40              Tesla Model 3 Long Range                580
# 41             Tesla Model 3 Performance                567
# 44         Tesla Model X Long Range Plus                561
# 48                 Volkswagen ID.3 Pro S                549
# 45             Tesla Model X Performance                548
# 49                   Volkswagen ID.4 1st                500
# 16                         Jaguar I-Pace                470
# 31  Porsche Taycan 4S (Performance Plus)                463
#
#     Minimal price (gross) [PLN]
# 42                       368990
# 43                       443990
# 40                       235490
# 41                       260490
# 44                       407990
# 48                       179990
# 45                       482990
# ...

# %% [markdown]
# Step 2: Visualize the Top Performers
# We can visualize the top-performing EVs for each metric using bar charts or scatter plots.

# %%
# Plotting the top-performing EVs by Range, Acceleration, and Maximum Speed

plt.figure(figsize=(15, 12))

# Top 10 EVs by Range
plt.subplot(3, 1, 1)
sns.barplot(x=top_range_vehicles['Range (WLTP) [km]'], y=top_range_vehicles['Car full name'], palette='Blues')
plt.title('Top 10 EVs by Range (WLTP)')

# Top 10 EVs by Acceleration
plt.subplot(3, 1, 2)
sns.barplot(x=top_acceleration_vehicles['Acceleration 0-100 kph [s]'], y=top_acceleration_vehicles['Car full name'], palette='Greens')
plt.title('Top 10 EVs by Acceleration (0-100 kph)')

# Top 10 EVs by Maximum Speed
plt.subplot(3, 1, 3)
sns.barplot(x=top_speed_vehicles['Maximum speed [kph]'], y=top_speed_vehicles['Car full name'], palette='Oranges')
plt.title('Top 10 EVs by Maximum Speed')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 8: Inferential Statistics – Hypothesis Testing: Test whether there is a significant difference
# in the average Engine power [KM] of vehicles manufactured by two leading manufacturers i.e.
# Tesla and Audi. What insights can you draw from the test results?
# (Conduct a two sample t-test using ttest_ind from scipy.stats module) (10 Marks)

# %%
from scipy.stats import ttest_ind

# Filter the data for Tesla and Audi
tesla_data = df[df['Make'] == 'Tesla']['Engine power [KM]']
audi_data = df[df['Make'] == 'Audi']['Engine power [KM]']

# Perform the two-sample t-test
t_stat, p_value = ttest_ind(tesla_data, audi_data, nan_policy='omit')

# Output the t-statistic and p-value
print(f"T-statistic: {t_stat}, P-value: {p_value}")

# Hypothesis Testing Conclusion
if p_value < 0.05:
    print("Reject null hypothesis: Significant difference in engine power between Tesla and Audi vehicles")
else:
    print("Fail to reject null hypothesis: No significant difference in engine power between Tesla and Audi vehicles")
# Out:
# T-statistic: 1.7024444538261416, P-value: 0.11672692675082785
# Fail to reject null hypothesis: No significant difference in engine power between Tesla and Audi vehicles

# %% [markdown]
# ### Task 9: Predictive Insights for Future Trends : Forecast future trends in the electric vehicle market. (10 Marks)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Check if the dataset contains a year column (assuming it's 'Year')
# If 'Year' column is present, proceed with regression

# Example: Predicting Price based on Year (adjust column names as needed)
if 'Year' in df.columns:
    # Filter relevant columns: 'Year' and 'Price_PLN'
    df_year = df[['Year', 'Minimal price (gross) [PLN]']].dropna()

    # X (Year) and y (Price) for prediction
    X = df_year[['Year']]
    y = df_year['Minimal price (gross) [PLN]']

    # Create and fit the regression model
    model = LinearRegression()
    model.fit(X, y)

    # Predict future trends (e.g., for the next 5 years)
    future_years = np.array([[2025], [2026], [2027], [2028], [2029]])
    predicted_prices = model.predict(future_years)

    # Plotting the prediction
    plt.figure(figsize=(10, 6))
    plt.scatter(df_year['Year'], df_year['Minimal price (gross) [PLN]'], color='blue', label='Historical Data')
    plt.plot(future_years, predicted_prices, color='red', linestyle='dashed', label='Predicted Prices')
    plt.title('Predicted Price of Electric Vehicles Over Time')
    plt.xlabel('Year')
    plt.ylabel('Price (PLN)')
    plt.legend()
    plt.show()

    # Display predictions for future years
    print("Predicted Prices for the next 5 years:")
    for year, price in zip(future_years.flatten(), predicted_prices):
        print(f"Year {year}: {price:.2f} PLN")
else:
    print("No 'Year' column available for time-based forecasting. Consider forecasting based on other features.")
# Out:
# No 'Year' column available for time-based forecasting. Consider forecasting based on other features.

# %% [markdown]
# ### Task 10: Recommendations and Conclusion: Provide actionable insights based on your analysis. (10 Marks)

# %% [markdown]
# #### Key Insights and Recommendations:
# 1. Engine power and battery capacity are positively correlated with the price.
# 2. Vehicles with higher battery capacity tend to have greater range, which may appeal to consumers with range concerns.
# 3. Drive type influences price, with all-wheel drive models being generally more expensive.
# 4. To appeal to budget-conscious consumers, manufacturers could focus on optimizing battery capacity for longer ranges without increasing engine power.

# %% [markdown]
# ### Insights on the Growth of Electric Vehicles
# #### Increasing Variety in Models:
# The dataset contains 53 unique models from 20 manufacturers, indicating a significant expansion in the EV market. This growth reflects increased competition and innovation as manufacturers aim to cater to diverse consumer preferences.
#
# #### Advancements in Battery Technology:
# Battery capacities range from small to large, with improvements directly correlating to the range (WLTP). High-capacity batteries suggest advancements in energy storage, enabling EVs to travel farther, which is essential for widespread adoption.
#
# #### Performance Improvements:
# Features like engine power, acceleration, and maximum speed demonstrate that EVs are not just eco-friendly alternatives but also capable of competing with traditional internal combustion engine vehicles in terms of performance.
#
# #### Consumer-Oriented Features:
# The inclusion of data on dimensions, boot capacity, and seating capacity highlights that EVs are being designed to meet varied consumer needs, from compact urban cars to spacious family vehicles.
#
# #### Diverse Price Points:
# The dataset includes vehicles at different price levels, indicating efforts by manufacturers to cater to both budget-conscious and premium market segments. This diversification is a sign of the growing accessibility of EVs.
#
# #### Technological Advancements:
# High maximum DC charging power values suggest improvements in fast-charging technology, reducing charging times and addressing a key barrier to EV adoption.
#
# #### Global Trends in Adoption:
# The steady growth in the number of manufacturers and models in the dataset aligns with global trends in EV adoption. Governments worldwide are promoting EVs through subsidies, tax benefits, and regulations on emissions, which further fuel this growth.
# What the Data Suggests About EV Market Growth
#
# The data highlights the evolution of EV technology, including improved range, performance, and affordability, which are critical drivers for adoption.
# The variety of models and manufacturers reflects a mature and competitive market, with EVs becoming a viable option for a broader range of consumers.
# Trends in battery and charging technology demonstrate the industry's commitment to overcoming challenges like range anxiety and charging infrastructure.
# The focus on both performance and practicality indicates a shift in consumer perception of EVs as mainstream alternatives to traditional vehicles.

# %% [markdown]
# #### Actionable Recommendations:
# Focus on Consumer Segmentation:
#
# Different EV features like battery capacity, range, and performance appeal to different customer segments. Manufacturers should focus on economy models with moderate range and battery capacity for price-sensitive buyers and premium models for performance-seeking buyers with high-end specs.
# Invest in Battery Technology:
#
# To stay competitive, manufacturers should prioritize innovation in battery efficiency, charging speeds, and energy density. Longer battery life and faster charging will not only improve performance but also increase consumer adoption.
# Incentivize Budget-Friendly Options:
#
# Given the growing interest in electric vehicles, manufacturers should explore government incentives or partnerships to lower the cost of EVs, particularly for first-time EV buyers or those who are more focused on affordability rather than performance.
# Promote the Environmental Benefits:
#
# As the demand for sustainable and green solutions grows, manufacturers should emphasize the environmental benefits of EVs in their marketing campaigns to attract eco-conscious consumers.
# Focus on Infrastructure Development:
#
# The adoption of electric vehicles will be heavily influenced by the availability of charging infrastructure. Manufacturers should collaborate with government agencies and private players to enhance the charging network to make EVs more accessible to a broader population.
# Trend Adaptation:
#
# As consumer preferences shift, particularly towards longer range and faster charging, manufacturers should adopt agile product development cycles to quickly adapt to these demands and remain competitive.
# Focus on Advanced Features:
#
# Given the rising importance of in-car technology (e.g., infotainment, autonomous driving features), EV manufacturers should integrate these advancements into their models to appeal to tech-savvy consumers.
# Conclusion:
# The electric vehicle market is undergoing rapid transformation, with increasing demand for better performance, longer ranges, and affordable pricing. Based on the insights from the dataset, manufacturers should focus on optimizing battery technology, strategic product positioning (luxury vs. budget models), and market segmentation to cater to the different needs of consumers. Continuous innovation and a focus on sustainability will be key factors in staying competitive in the EV market. By following these actionable recommendations, manufacturers can not only stay ahead in the market but also contribute to the global transition to electric vehicles.
